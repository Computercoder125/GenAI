# %% [markdown]
# <a href="https://colab.research.google.com/github/Computercoder125/GenAI/blob/main/HW1/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1/27/26
#
# Assignment 1
#
# Purpose: To show how model outputs can change by varying temperature (and even different models themselves)

# %% [markdown]
# Original Sentence: I am going to have chicken nuggets for

# %% [markdown]
# ![Image 1-28-26 at 12.55 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Image 1-28-26 at 12.59 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Did your model repeat any words or phrases?**
#
#
# The model did repeat words in every iteration. This happened because it was trying to learn the pattern of the sentence as it went along. When I added new words, the model would often start from the beginning of the sentence again to make sure the next part made sense. This created a "staircase" effect where the response grew longer each time, repeating the "chicken nugget" phrase to maintain the structure of the prompt.
#
#
# **Did the model use real words, or did it start outputting random characters and punctuation? Explain how the "Probability Distribution" changed to allow this.**
#
# Even at high temperatures, the model used real words and outputted them one at a time. It also used correct punctuation marks like exclamation points and periods. This occurred because the "Probability Distribution" changed based on the temperature settings. At a low temperature, the distribution is very narrow, so the model only picks the most likely word. At a high temperature of 2.0, the distribution flattens out, which lets the model pick "less likely" words, creating more chaotic and creative results while still staying within the list of real words it knows.
#
# **If you were building a medical AI to give prescriptions or advice, which temperature would you use?**
#
# In this situation, I would use a lower temperature of 0.5 or less. This is because accuracy matters more than anything else when you are dealing with someone’s illness or health issues. Using a low temperature makes the model more deterministic, meaning it stays on the right path and gives the same safe, proven advice every time. You wouldn't want a medical AI to get "creative" with a prescription; you want it to be as accurate and predictable as possible.
#
# **If you were building an AI to write a surrealist dream-journal, which would you use?**
#
# In this scenario, I would use a higher temperature (around 2.0) to make the outputs more creative and chaotic. This would be perfect for a dream journal. Since dreams don't always make sense and are often very weird, the high temperature allows the model to jump between random ideas—like going from chicken nuggets to salad or steak—in a way that feels like a dream.

# %% [markdown]
# ## Distilled Version

# %% [markdown]
# ![Image 1-28-26 at 1.00 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Image 1-28-26 at 1.01 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Comparsion

# %% [markdown]
# Both of the model outputs had a consistent pattern as temperature increased over time (ie. at lower temperatures the algorithm was greedy, but at higher temperatures the model picked other words, even though some were nonsensical). However, there are some distinct differences as discussed below:
#
#
#
# **Consistency in Pattern**: In both the GPT-2 and DistilGPT2 runs, a low temperature of 0.1 resulted in a "Conservative" response that was highly repetitive. For example, both models tended to loop on words like "dinner" or restate the initial prompt multiple times. This shows that at low temperatures, both algorithms are "greedy," meaning they strictly pick the most probable next word without taking any risks.
#
# **Creative Differences (T=0.8)**: At the "Creative" setting, you can see the impact of DistilGPT2 being a lighter model. While both models started to vary their word choices (like switching "dinner" to "dessert" or "of these"), the specific paths they took were different. Because DistilGPT2 has 6 layers and 82 million parameters (compared to GPT-2's 12 layers and 124 million), it has a slightly higher "perplexity," meaning it is more likely to make different associations than the larger model.
#
# **The "Chaos" Temperature (T=2.0)**: At the maximum temperature, both models produced nonsensical "word salad," but the type of chaos varied. In your first run, the model hallucinated specific details like "thanks to the lady" and a "gen AI assignment". In the DistilGPT2 run, the chaos was equally present, but the model reached it faster and with even less logical connection to the original prompt. This highlights that smaller models like DistilGPT2 are often less robust at high temperatures and will lose their "thread of logic" more quickly than the standard GPT-2.
