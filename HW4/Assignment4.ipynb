# %% [markdown]
# <a href="https://colab.research.google.com/github/Computercoder125/GenAI/blob/main/HW4/Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Sean Gor
# #3/17/26
# #Assignment 4 To deal with different retrievers in a RAG system and understand their tradeoffs/focus when conducting similarity searches on various queries based on a topic. Also to deal with reranking.

# %% [markdown]
# Trial A (Naive Similarity Retriever) Results:

# %%
--- Testing: Keyword Search Test ---
Query: When was Ludwig Van Beethoven Born?
Rank 1: [Beethoven timeline: 21 key dates from an extraordinary life | Classical Music.pdf] 20 Beethoven masterpieces you must hear Beethoven timeline: the early years 1. 16 December 1770: the Beethoven story begins Ludwig van Beethoven was born in Bonn, to Johann and Maria van Beethoven. Jo...
Rank 2: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf]  Ludwig van Beethoven Ludwig vanBeethoven, lithograph after an 1819 portraitby Ferdinand Schimon, c. 1870. When the "what if" happens, ADPprepares you for the “what’s next. " SPONSORED BY SPONSORED B...
Rank 3: [Beethoven timeline: 21 key dates from an extraordinary life | Classical Music.pdf] Ludwig van Beethoven (1770–1827) is widely considered one of the greatest composers in Western music history. His life and works mark a critical bridge between the Classical and Romantic eras. Display...

--- Testing: Conceptual Search Test ---
Query: Why is Beethoven considered a bridge between the Classical and Romantic eras?
Rank 1: [Beethoven timeline: 21 key dates from an extraordinary life | Classical Music.pdf] Ludwig van Beethoven (1770–1827) is widely considered one of the greatest composers in Western music history. His life and works mark a critical bridge between the Classical and Romantic eras. Display...
Rank 2: [Beethoven timeline: 21 key dates from an extraordinary life | Classical Music.pdf] 20 Beethoven masterpieces you must hear Beethoven timeline: the early years 1. 16 December 1770: the Beethoven story begins Ludwig van Beethoven was born in Bonn, to Johann and Maria van Beethoven. Jo...
Rank 3: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf] Widely regarded as the greatest composer who ever lived,Ludwig van Beethoven dominates a period of musicalhistory as no one else before or since. Rooted in theClassical traditions of Joseph Haydn and ...

--- Testing: Technical Search Test ---
Query: What is Piano Sonata No. 14 in C-sharp minor, Op. 27, No. 2, and why is it called the Moonlight Sonata?
Rank 1: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf] 3/17/26, 4:56 PMMoonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica Page 1 of 10https://www.britannica.com/topic/Moonlight-Sonata  Explore Britannica's Newest Newsletter: Mon...
Rank 2: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf] The Moonlight Sonata was structurally and stylistically remarkable in its day. Most sonatasof the late 17th and early 18th centuries consisted of a reasonably animated, thematicallywell-defined first ...
Rank 3: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf] 3/17/26, 4:56 PMMoonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica Page 5 of 10https://www.britannica.com/topic/Moonlight-Sonata...

# %% [markdown]
# Final RAG Answer:

# %% [markdown]
# Trial A: Vector

# %% [markdown]
# A. Factual

# %% [markdown]
# QUESTION: When was Ludwig Van Beethoven Born?
#
# ANSWER:
# Ludwig van Beethoven was born on December 16, 1770, in Bonn. He is considered one of the greatest composers in Western music history. His life and works bridge the Classical and Romantic eras.

# %% [markdown]
# B. Conceptual

# %% [markdown]
# QUESTION: Why is Beethoven considered a bridge between the Classical and Romantic eras?
#
# ANSWER:
# Beethoven's works are considered a bridge because they were rooted in the Classical traditions of composers like Haydn and Mozart. However, his music also introduced bold innovations in structure and conveyed a new depth of emotion, reflecting personal struggle, heroism, and humanistic ideals. This blend of traditional foundations with revolutionary emotional expression and thematic concerns positioned him as a critical link between the Classical and Romantic eras.

# %% [markdown]
# C. Technical

# %% [markdown]
# QUESTION: What is Piano Sonata No. 14 in C-sharp minor, Op. 27, No. 2, and why is it called the Moonlight Sonata?
#
# ANSWER:
# Piano Sonata No. 14 in C-sharp minor, Op. 27, No. 2, also known as the Moonlight Sonata, is a remarkable work by Beethoven. It was structurally and stylistically unique for its time, featuring a dreamy first movement, a livelier second, and a tempestuous final movement. The provided context does not explain why it is called the Moonlight Sonata.

# %% [markdown]
# **Trial B (mmr retriver) chunking results **

# %% [markdown]
# --- Testing: Keyword Search Test ---
# Query: When was Ludwig Van Beethoven Born?
# Rank 1: [Beethoven timeline: 21 key dates from an extraordinary life | Classical Music.pdf] 20 Beethoven masterpieces you must hear Beethoven timeline: the early years 1. 16 December 1770: the Beethoven story begins Ludwig van Beethoven was born in Bonn, to Johann and Maria van Beethoven. Jo...
# Rank 2: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf]    CITE Ludwig van BeethovenGerman composer Raymond L. Knapp•All Britannica Editors Mar. 13, 2026 •History Britannica AI Ask Anything Quick Summary     See all related content Byname of: Piano ...
# Rank 3: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf] Widely regarded as the greatest composer who ever lived,Ludwig van Beethoven dominates a period of musicalhistory as no one else before or since. Rooted in theClassical traditions of Joseph Haydn and ...
#
# --- Testing: Conceptual Search Test ---
# Query: Why is Beethoven considered a bridge between the Classical and Romantic eras?
# Rank 1: [Beethoven timeline: 21 key dates from an extraordinary life | Classical Music.pdf] Ludwig van Beethoven (1770–1827) is widely considered one of the greatest composers in Western music history. His life and works mark a critical bridge between the Classical and Romantic eras. Display...
# Rank 2: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf] The Moonlight Sonata was structurally and stylistically remarkable in its day. Most sonatasof the late 17th and early 18th centuries consisted of a reasonably animated, thematicallywell-defined first ...
# Rank 3: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf] individual. He revealed more vividly than any of hispredecessors the power of music to convey a philosophy oflife without the aid of a spoken text; and in certain of hiscompositions is to be found the...
#
# --- Testing: Technical Search Test ---
# Query: What is Piano Sonata No. 14 in C-sharp minor, Op. 27, No. 2, and why is it called the Moonlight Sonata?
# Rank 1: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf] 3/17/26, 4:56 PMMoonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica Page 1 of 10https://www.britannica.com/topic/Moonlight-Sonata  Explore Britannica's Newest Newsletter: Mon...
# Rank 2: [Beethoven's Piano Sonatas: John Suchet's guide to the music - Classic FM.pdf] theme of the ﬁrst movement rising from the depths. Once again, as with the Pathétique, the middle movement is simplicity itself, almost a theme on a single note. The entire work has such nobility and ...
# Rank 3: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf] The Moonlight Sonata was structurally and stylistically remarkable in its day. Most sonatasof the late 17th and early 18th centuries consisted of a reasonably animated, thematicallywell-defined first ...

# %% [markdown]
# **Trial B: MMR Rag Results**

# %% [markdown]
# A: factual:

# %% [markdown]
# QUESTION: When was Ludwig Van Beethoven Born?
# ANSWER: Ludwig van Beethoven was born on December 16, 1770. He was born in Bonn to Johann and Maria van Beethoven. His father was a singer and instrumentalist at the court of Clemens-August.

# %% [markdown]
# B. Conceptual:

# %% [markdown]
# QUESTION: Why is Beethoven considered a bridge between the Classical and Romantic eras?
#
# ANSWER:
# Beethoven is considered a bridge between the Classical and Romantic eras because his life and works marked a critical transition. He innovated classical musical forms, widening the scope of sonatas, symphonies, concertos, and quartets. Furthermore, he became a fountainhead for much that characterized the Romantics, revealing music's power to convey emotion and a philosophy of life, as seen in his ideal of program music.

# %% [markdown]
# C. Technical

# %% [markdown]
# QUESTION: What is Piano Sonata No. 14 in C-sharp minor, Op. 27, No. 2, and why is it called the Moonlight Sonata?
#
# ANSWER:
# Piano Sonata No. 14 in C-sharp minor, Op. 27, No. 2, commonly known as the Moonlight Sonata, is a solo piano work by Ludwig van Beethoven, completed in 1801. It is particularly admired for its mysterious, gently arpeggiated first movement. The nickname "Moonlight Sonata" originated in the 1830s when German poet Ludwig Rellstab likened its first movement to a boat floating in the moonlight on Switzerland’s Lake Lucerne.

# %% [markdown]
# **Trail C (Hybrid Retriver) Output:**

# %% [markdown]
# --- Testing: Keyword Search Test ---
# Query: When was Ludwig Van Beethoven Born?
# Rank 1: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf]  Ludwig van Beethoven Ludwig vanBeethoven, lithograph after an 1819 portraitby Ferdinand Schimon, c. 1870. When the "what if" happens, ADPprepares you for the “what’s next. " SPONSORED BY SPONSORED B...
# Rank 2: [Beethoven timeline: 21 key dates from an extraordinary life | Classical Music.pdf] 20 Beethoven masterpieces you must hear Beethoven timeline: the early years 1. 16 December 1770: the Beethoven story begins Ludwig van Beethoven was born in Bonn, to Johann and Maria van Beethoven. Jo...
# Rank 3: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf]    CITE Ludwig van BeethovenGerman composer Raymond L. Knapp•All Britannica Editors Mar. 13, 2026 •History Britannica AI Ask Anything Quick Summary     See all related content Byname of: Piano ...
#
# --- Testing: Conceptual Search Test ---
# Query: Why is Beethoven considered a bridge between the Classical and Romantic eras?
# Rank 1: [Beethoven timeline: 21 key dates from an extraordinary life | Classical Music.pdf] Ludwig van Beethoven (1770–1827) is widely considered one of the greatest composers in Western music history. His life and works mark a critical bridge between the Classical and Romantic eras. Display...
# Rank 2: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf] The Moonlight Sonata was structurally and stylistically remarkable in its day. Most sonatasof the late 17th and early 18th centuries consisted of a reasonably animated, thematicallywell-defined first ...
# Rank 3: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf] 3/17/26, 4:56 PMMoonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica Page 3 of 10https://www.britannica.com/topic/Moonlight-Sonata Top Questions What is Ludwigvan Beethovenkno...
#
# --- Testing: Technical Search Test ---
# Query: What is Piano Sonata No. 14 in C-sharp minor, Op. 27, No. 2, and why is it called the Moonlight Sonata?
# Rank 1: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf] 3/17/26, 4:56 PMMoonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica Page 1 of 10https://www.britannica.com/topic/Moonlight-Sonata  Explore Britannica's Newest Newsletter: Mon...
# Rank 2: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf] The Moonlight Sonata was structurally and stylistically remarkable in its day. Most sonatasof the late 17th and early 18th centuries consisted of a reasonably animated, thematicallywell-defined first ...
# Rank 3: [Beethoven's Piano Sonatas: John Suchet's guide to the music - Classic FM.pdf] theme of the ﬁrst movement rising from the depths. Once again, as with the Pathétique, the middle movement is simplicity itself, almost a theme on a single note. The entire work has such nobility and ...

# %% [markdown]
# **Trial C: Hybrid Search RAG Results**

# %% [markdown]
# A. factual

# %% [markdown]
# QUESTION: When was Ludwig Van Beethoven Born?
#
# ANSWER:
# Ludwig van Beethoven was born on December 16, 1770. He was born in Bonn to Johann and Maria van Beethoven. His talent was evident early on, and he began studying composition by age ten.

# %% [markdown]
# B. Conceptual

# %% [markdown]
# QUESTION: Why is Beethoven considered a bridge between the Classical and Romantic eras?
#
# ANSWER:
# Beethoven is considered a bridge between the Classical and Romantic eras because his life and works mark a critical transitional period. He was a predominant musical figure during this time, producing bold and innovative compositions. Though not a Romantic himself, he became a fountainhead for many characteristics of the Romantic era, such as expressing emotion and innovating musical forms, influencing subsequent composers.

# %% [markdown]
# C. Technical

# %% [markdown]
# What is Piano Sonata No. 14 in C-sharp minor, Op. 27, No. 2, and why is it called the Moonlight Sonata?
#
# ANSWER:
# Piano Sonata No. 14 in C-sharp minor, Op. 27, No. 2 is a renowned work by Ludwig van Beethoven, also known as the Moonlight Sonata. It was structurally and stylistically remarkable for its time, featuring a dreamy first movement, a livelier second, and a tempestuous final movement. The provided context does not explain why it is called the Moonlight Sonata.

# %% [markdown]
# Questions:
# 1. Compare Trial A to Trial B. Did the Naive approach return three chunks that all said the same thing? Did MMR provide a more "complete" picture for your conceptual question?
#
# In Trial A, most chunks were similar throughout the technical, factual and conceptual questions. For example, the Naive approach returned multiple chunks from the same PDF (the Moonlight Sonata Britannica document). These chunks were essentially discussing the same topic, meaning the retriever produced redundant results, rather than diverse information.
# However, MMR retrieval did provide a more complete picture of these results because by definition, it balances relevance and diversity when conducting the search. For example, when inputting my question, “Why is Beethoven considered a bridge between the Classical and Romantic eras?,” the model looked at a wide range of sources and overall provided a broader explanation than the naive search done in trial A, like historical context of work done.
#
#
# 2. In Trial C, did the Hybrid search find information that the Vector-only searches (A and B) missed? Hint. Look for specific dates, names, or technical IDs in your documents.
#
# Hybrid search did not retrieve entirely new information compared with the vector-only retrievers, since the key facts such as Beethoven’s birth date (16 December 1770) and Moonlight Sonata technical title (Op. 27, No. 2) were already retrieved in earlier trials. However, Hybrid retrieval strengthens performance for queries containing exact names, dates, and technical identifiers because the BM25 component prioritizes documents that match those keywords directly.

# %% [markdown]
# 3. If a retriever failed to find the answer, did the LLM admit it didn't know, or did it use its internal knowledge to "guess"? Explain how retrieval quality directly impacts "Groundedness."
#
# There were not many cases where the retriever completely failed to find relevant information. However, in the technical prompt about why the Moonlight Sonata was created, I noticed some differences between the retrievers. With the vector and hybrid searches, the LLM explicitly said it did not have enough information in the retrieved context to answer the question. However, the MMR search (which focuses on balancing relevance and diversity) sometimes tried to guess an explanation based on the partial context it received.
#
# This shows how retrieval quality directly affects groundedness. In a RAG system, the LLM is supposed to answer questions using the information that was retrieved from the documents. If the retriever provides strong and relevant chunks, the model’s response will be grounded in those sources. If the retriever fails to find the right information, the LLM either has to say it does not know or rely on its internal knowledge to make a guess. Because of this, poor retrieval can lead to answers that are less accurate or not fully supported by the documents, while good retrieval keeps the responses grounded and more trustworthy.

# %% [markdown]
# 4. Based on your specific dataset, which retrieval strategy would you put into production and why?
#
# Based on my dataset, I would put the Hybrid retrieval strategy into production. Hybrid search combines semantic vector retrieval with lexical keyword search (BM25), which allows it to capture both the meaning of a query and exact terms like names, dates, or technical identifiers.
# In my experiments, Hybrid retrieval often pulled information from a variety of relevant sources, rather than repeatedly returning chunks from the same document. This helped provide broader context and improved answer quality. For example, the factual and conceptual questions about Beethoven retrieved useful timeline and biography information from different documents. Additionally, under this type of retrieval, the model admitted when it did not know something, such as the question about why the Moonlight Sonata was created. Instead of hallucinating an explanation, the model correctly indicated that the retrieved documents did not contain that information. This behavior demonstrates strong groundedness, since the response stayed aligned with the retrieved context rather than relying on internal guesses.

# %% [markdown]
# Chart:

# %% [markdown]
# ![Image 3-18-26 at 4.22 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# EXTRA CREDIT:

# %% [markdown]
# Output of my Reranker (Architecture: cross-encoder reranker, pipeline pattern: contextual compression)

# %% [markdown]
# --- Before Reranking ---
# Rank 1: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf] 3/17/26, 4:56 PMMoonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica Page 1 of 10https://www.britannica.com/topic/Moonlight-Sonata  Explore Britannica's Newest Newsletter: Mon...
# Rank 2: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf] The Moonlight Sonata was structurally and stylistically remarkable in its day. Most sonatasof the late 17th and early 18th centuries consisted of a reasonably animated, thematicallywell-defined first ...
# Rank 3: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf] 3/17/26, 4:56 PMMoonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica Page 5 of 10https://www.britannica.com/topic/Moonlight-Sonata...
# Rank 4: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf] 3/17/26, 4:56 PMMoonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica Page 3 of 10https://www.britannica.com/topic/Moonlight-Sonata Top Questions What is Ludwigvan Beethovenkno...
# Rank 5: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf] 3/17/26, 4:56 PMMoonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica Page 8 of 10https://www.britannica.com/topic/Moonlight-Sonata...
#
# --- After Reranking ---
# Rank 1: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf] The Moonlight Sonata was structurally and stylistically remarkable in its day. Most sonatasof the late 17th and early 18th centuries consisted of a reasonably animated, thematicallywell-defined first ...
# Rank 2: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf] 3/17/26, 4:56 PMMoonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica Page 1 of 10https://www.britannica.com/topic/Moonlight-Sonata  Explore Britannica's Newest Newsletter: Mon...
# Rank 3: [Moonlight Sonata | Piano Sonata, Op. 27, No. 2 & Classical Music | Britannica.pdf]    CITE Ludwig van BeethovenGerman composer Raymond L. Knapp•All Britannica Editors Mar. 13, 2026 •History Britannica AI Ask Anything Quick Summary     See all related content Byname of: Piano ...

# %% [markdown]
# Analysis:

# %% [markdown]
# Did the Reranker move a more relevant chunk from the "bottom" of the list to the "top"?
#
# Explain the trade-off: Is the extra latency, i.e., time taken to rerank, worth the improvement in precision for your specific use case?

# %% [markdown]
# Yes, the reranker improved the ranking by moving a more meaningful explanatory chunk to the top. Before reranking, the top result mostly contained page header and metadata from the Moonlight Sonata Britannica article rather than the most informative content. After reranking, the first result became the chunk explaining that the piece was structurally and stylistically remarkable, which was more relevant to the question. The reranker did not introduce new information, but it improved precision by reducing noise and prioritizing the most useful chunk.
#
# Regarding the trade-off, the reranking step adds some extra latency because the system must first retrieve documents and then rescore them. However, for my Beethoven dataset, I think the additional latency is worth it for more difficult questions because it helps the LLM receive cleaner and more grounded context, which can lead to more accurate answers.
