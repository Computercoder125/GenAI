# %% [markdown]
# <a href="https://colab.research.google.com/github/Computercoder125/GenAI/blob/main/HW2/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sean Gor
# February 10 2026
# Assignment 2
#
# Purpose: To explore what images look like during different steps of removing noise (underbaked, optimal and oversaturated states), and to explore a scenario with negative prompts

# %% [markdown]
# ![Image 2-11-26 at 1.22 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Image from Trial A:

# %% [markdown]
# ![Image 2-11-26 at 1.23 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Image from Trial B:

# %% [markdown]
# ![Image 2-11-26 at 1.24 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Image from Trial C:

# %% [markdown]
# ![Image 2-11-26 at 1.25 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Questions:
#
# 1. Compare Trial A to Trial B. Why does 5 steps result in a blurry ghost of an image?
#
# In Trial A, the 5 steps result in a "blurry ghost" because the diffusion process is stopped way too early. Since the model starts with a canvas of pure randomness (noise), it uses each step to gradually "trim" away that noise to find the shapes you asked for. At only 5 steps, the AI has barely started its work; it has only moved a tiny amount of noise, leaving the image looking like a faint, unresolved smear rather than a clear terminal.
#
# As opposed to Trial B, where the model is given 50 steps, it has ten times the "cleanup" time to remove all that remaining noise. This allows the AI to actually finish the job, turning the blurry green blobs from Trial A into sharp, recognizable lines of code and screen reflections. Essentially, Trial A is like looking at a rough sketch where you can barely see the idea, while Trial B is the finished drawing where all the messy "noise" has been erased.
#
# 2. In Trial C, look at the colors. Did they become more realistic, or did they start to become too bright/dark? Explain why.
#
# In Trial C, the colors definitely did not become more realistic; instead, they became way too bright and dark, giving the image a "deep-fried" or heavily distorted look. This happened because of the high Guidance Scale of 30. When the guidance is pushed that high, the AI is basically being "forced" to follow every single word of the prompt as literally as possible.
# Because the model is trying so hard to obey the prompt at every one of the 50 steps, the mathematical weights get pushed to their absolute limits. This leads to extreme saturation and high contrast, where the neon greens and dark shadows become "over-baked". While 50 steps usually helps with detail, combining it with such a high guidance scale causes the colors to bleed and collapse because the model is over-correcting itself to try and be "perfect," which actually ruins the realistic look of the image.
#
# 3. Does doubling the steps double the time it takes to generate the image? Why or why not?
#
# I think doubling the steps does take about double the time to generate the image, or at least it's very close to it. My reasoning is that since the model has to "remove noise" in a specific sequence, adding more steps is like adding more laps to a race. The AI can't skip ahead; it has to perform a full mathematical calculation for every single step you set.
# So, if you go from 25 steps to 50 steps, the computer basically has to do twice the amount of "work" or math equations to finish the denoising process. Even though the final image might look a lot better with more steps, each step takes a consistent amount of processing time, which makes it very plausible that the total time spent would double right along with the step count

# %% [markdown]
# **Extra Credit (Negative Prompting):**

# %% [markdown]
# Image:

# %% [markdown]
# ![Image 2-11-26 at 1.27 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Questions:

# %% [markdown]
# 1. Explain the observed results:
#
# When I added the negative prompt to block things like 'green' and 'text,' the image changed completely while still keeping the cyberpunk vibe. Instead of the usual green 'Matrix' style code, the model shifted the color palette to deep purples and pinks to fill the void. The screen doesn't show letters anymore; instead, it looks more like abstract light patterns or hardware interfaces, which shows that the AI had to get creative to follow my instructions.
#
# 2. Why is a Negative Prompt more powerful than just changing the positive prompt?
# I think a Negative Prompt is more powerful because it gives the AI a clear 'no-go' zone. If I just change the positive prompt, the AI might still include green or text because it associates them so strongly with 'hackers.' By using a negative prompt, I am actively pushing the model away from those specific concepts during every step of the denoising process, which forces it to find a brand-new direction it wouldn't have taken otherwise.
#
# 3. Does it still look like a hacker terminal? Rate the result (1–10):
#
# I would rate this a 7 or 8 on the cyberpunk theme. Even without the green text, it still looks like a high-tech terminal because of the neon lighting and the overall geometry of the monitors. It proves that you don't need the 'cliché' green code to make something feel like a cyberpunk hacker scene!
